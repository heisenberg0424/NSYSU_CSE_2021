# %%
import captcha

# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
temp = Image.open('screenshot.png')
temp = temp.crop((410,144,530,169))
#temp = temp.resize((124,24))
plt.imshow(np.asarray(temp))

# %%
print(captcha.captcha(temp))
# Out:
# 7912
